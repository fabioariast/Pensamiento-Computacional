# %% [markdown]
# <a href="https://colab.research.google.com/github/fabioariast/Pensamiento-Computacional/blob/main/00_Glosario(Python).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. División entera (`//`)
#
#
# >Division entre números el cual el resultado es siempre entero por tanto se redondea al entero menor.
#
# ---
# 2. Expresiones
#
#
# >Una colección de operadores y números.
#
# ---
# 3. Valor
#
#
# >Es el resultado de una expresión.
# ---
# 4. Error: SyntaxError
#
#
# >Ocurre uando llamo una función y comento un error en su escritura (por ejejmplo: abs 42, es un error pues no puse los parentesis en el 42)
# ---
# 5. Función `len()`
#
# >Cuenta la cantidad de caracteres que tiene un string. Si no pongo los parentesis tengo un error de Sintaxis
# ---
# 6. Error: TypeError
#
# >Cuando se ejecuta una operación que no esta asociada a un tipo. (ej: dividir un string, pues con string solo puedo multiplicar y sumar)
# ---
# 7. Debugging
#
# >proceso de buscar, encontrar y corregir errores o fallos (conocidos como bugs) en el código fuente de un programa de software para que funcione bien.
# ---
# 8. Diagrams
#
# >Es una librería de código abierto en Python que permite dibujar arquitecturas de sistemas en la nube utilizando código en lugar de herramientas de diseño visual.
# ---
# 9. Statements
#
# >Statement que le da un valor a una variable (n = 10)
# ---
# 10. Keywords
#
# >Palabra reservada de Python que no se puede usar como nombre de variable (class, if, for, etc.)
# ---
# 11. import statement
#
# >Statement que carga un módulo para poder usar sus variables y funciones
# ---
# 12. module
#
# >Archivo con código Python (funciones, variables) que se puede importar
# ---
# 13. dot operator
#
# >El . que se usa para acceder a algo dentro de un módulo (math.pi)
# ---
# 14. Error semántico
#
# >El programa corre sin errores, pero no hace lo que querías
# ---
# 15. runtime error
#
# >Error que detiene el programa mientras corre
# ---
# 16. function definition
#
# >Statement que crea una función
# ---
# 17. stack diagram
#
# >Representación gráfica de una pila de funciones y sus variables
# ---
# 18. frame
#
# >Caja en un stack diagram que representa una llamada a función
# ---
# 19. traceback
#
# >Lista de funciones en ejecución que se imprime cuando ocurre una excepción
